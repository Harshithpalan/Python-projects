# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithpalan/Python-projects/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Electricity Consumption Prediction using LSTM

# %% [markdown]
# ## 1. Data Preparation

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Sample Data
#
# For demonstration, I will create a synthetic time series dataset. In a real-world scenario, you would load your electricity consumption data here (e.g., from a CSV file).

# %%
# Generate synthetic data for demonstration
np.random.seed(42)
data = np.sin(np.linspace(0, 100, 1000)) + np.random.normal(0, 0.1, 1000)

# Convert to a DataFrame (assuming a single feature time series)
df = pd.DataFrame(data, columns=['consumption'])

print("Original data head:")
display(df.head())
print("Original data shape:", df.shape)
# Out:
# Original data head:
#    consumption
# 0     0.049671
# 1     0.086107
# 2     0.263634
# 3     0.448110
# 4     0.366372
# Original data shape: (1000, 1)

# %% [markdown]
# ### Data Scaling
#
# LSTM models often perform better with scaled data. We'll use `MinMaxScaler` to scale the consumption data to a range between 0 and 1.

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

print("Scaled data head:")
display(pd.DataFrame(scaled_data, columns=['consumption']).head())
# Out:
# Scaled data head:
#    consumption
# 0     0.507586
# 1     0.522378
# 2     0.594450
# 3     0.669343
# 4     0.636159

# %% [markdown]
# ### Create Time Series Sequences
#
# For LSTM, we need to transform our time series into sequences of input (X) and output (y) pairs. Each input sequence will consist of `look_back` time steps, and the output will be the next time step's value.

# %%
# Function to create sequences for LSTM
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:(i + look_back), 0])
        y.append(data[i + look_back, 0])
    return np.array(X), np.array(y)

look_back = 10 # Number of previous time steps to use as input features to predict the next time step
X, y = create_sequences(scaled_data, look_back)

# Reshape input to be [samples, time steps, features]
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

print("Shape of X (input sequences):")
print(X.shape)
print("Shape of y (target values):")
print(y.shape)

# Split data into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[0:train_size], X[train_size:len(X)]
y_train, y_test = y[0:train_size], y[train_size:len(y)]

print(f"\nTraining data size: {len(X_train)} samples")
print(f"Testing data size: {len(X_test)} samples")
# Out:
# Shape of X (input sequences):
# (990, 10, 1)
# Shape of y (target values):
# (990,)
#
# Training data size: 792 samples
# Testing data size: 198 samples

# %% [markdown]
# ## 2. LSTM Model Design

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

print("LSTM Model Summary:")
model.summary()
# Out:
# LSTM Model Summary:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. Model Training

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1, verbose=1)

# Plot training history
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.2835 - val_loss: 0.1364
# Epoch 2/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0801 - val_loss: 0.0416
# Epoch 3/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0235 - val_loss: 0.0221
# Epoch 4/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0166 - val_loss: 0.0142
# Epoch 5/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0118 - val_loss: 0.0090
# Epoch 6/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 7/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 8/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 9/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 10/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 11/20
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 12/20
# ...

# %% [markdown]
# ## 4. Prediction and Evaluation

# %%
# Make predictions on the test set
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert scaling for better interpretability
train_predict = scaler.inverse_transform(train_predict)
y_train_true = scaler.inverse_transform(y_train.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict)
y_test_true = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate RMSE for evaluation
from sklearn.metrics import mean_squared_error
train_rmse = np.sqrt(mean_squared_error(y_train_true, train_predict))
test_rmse = np.sqrt(mean_squared_error(y_test_true, test_predict))
print(f'Train RMSE: {train_rmse:.2f}')
print(f'Test RMSE: {test_rmse:.2f}')

# Plot actual vs. predicted values for the test set
plt.figure(figsize=(12, 6))
plt.plot(y_test_true, label='Actual Consumption')
plt.plot(test_predict, label='Predicted Consumption')
plt.title('Electricity Consumption: Actual vs. Predicted (Test Set)')
plt.xlabel('Time Step')
plt.ylabel('Consumption')
plt.legend()
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Train RMSE: 0.13
# Test RMSE: 0.12
