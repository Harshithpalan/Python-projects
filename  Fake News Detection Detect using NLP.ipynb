# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithpalan/Python-projects/blob/main/%20Fake%20News%20Detection%20Detect%20using%20NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Install the Kaggle API client

# %%
pip install kaggle

# %% [markdown]
# ## 2. Set up Kaggle credentials
#
# To download datasets from Kaggle, you need to provide your API key. Follow these steps:
#
# 1. Go to [Kaggle](https://www.kaggle.com/).
# 2. Log in or register.
# 3. Click on your profile picture in the top right corner and select "My Account".
# 4. Scroll down to the "API" section and click "Create New API Token". This will download a `kaggle.json` file.
# 5. Upload this `kaggle.json` file to your Colab environment. You can do this by clicking the folder icon on the left sidebar, then the upload icon.
# 6. Move the `kaggle.json` file to the correct directory and set permissions.

# %%
import os

# Create a .kaggle directory if it doesn't exist
# !mkdir -p ~/.kaggle

# Move the kaggle.json file to the .kaggle directory
# Make sure you have uploaded kaggle.json to your Colab files first.
# !mv kaggle.json ~/.kaggle/

# Set permissions for the kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json

print("Kaggle API key set up successfully!")
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Kaggle API key set up successfully!

# %% [markdown]
# ## 3. Download the dataset
#
# The dataset you mentioned is typically named `fake-news` on Kaggle. You can download it using the Kaggle API.

# %%
# Download the dataset
# !kaggle datasets download -d mrisdal/fake-news

# Unzip the dataset
# !unzip fake-news.zip

print("Dataset downloaded and unzipped successfully!")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mrisdal/fake-news
# License(s): CC0-1.0
# ...
# 100% 19.4M/19.4M [00:02<00:00, 8.44MB/s]
#
# Archive:  fake-news.zip
#   inflating: fake.csv
# Dataset downloaded and unzipped successfully!

# %% [markdown]
# ## 4. Load the dataset into a pandas DataFrame
#
# Now you can load the CSV files into pandas DataFrames.

# %%
import pandas as pd

# Load the main fake news dataset
fake_news_df = pd.read_csv('fake.csv')

# Display the first 5 rows of the dataset
print("Fake News Dataset Head:")
display(fake_news_df.head())

# Display basic info about the dataset
print("\nFake News Dataset Info:")
fake_news_df.info()
# Out:
# Fake News Dataset Head:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# ...
